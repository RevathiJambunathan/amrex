# %%
import yt

ds = yt.load("plot")
print(ds)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/yy/n3t7phv166784l2_qxkc06vr0000gp/T/ipykernel_23704/2071600741.py in <module>
# ----> 1 import yt
#       2
#       3 ds = yt.load("plot")
#       4 print(ds)
#
# ModuleNotFoundError: No module named 'yt'

# %%
print(ds.field_list)
# Out:
# [('boxlib', 'error'), ('boxlib', 'exact_solution'), ('boxlib', 'rhs'), ('boxlib', 'solution')]

# %%
ad = ds.all_data()

x = ad[("index", "x")]
rho = ad[("boxlib", "solution")]

# %%
import matplotlib.pyplot as plt

plt.plot(x, ad[("boxlib", "solution")])
plt.xlabel("x")
plt.ylabel("phi")
plt.show()

# %%
plt.plot(x, ad[("boxlib", "error")])
plt.xlabel("x")
plt.ylabel("error")
plt.show()
